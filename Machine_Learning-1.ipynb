# %% [markdown]
# <a href="https://colab.research.google.com/github/vipin0761/pwskills_DS/blob/main/Machine_Learning-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Explain the following with an example
#
# a. Artificial Inttelligence -- some application that can perform it's own task without any human intervention.
# e.g. -- a system to enter and study blood composition in a lab trained to identify certain deficiencies
#
# b. Machinne Learning -- it is a subfield of artificial intelligence that gives computers the ability to learn without being programmed.
# e.g. -- computers learn from a dataset of human blood composition to draw conclusions about normal levels of various components in blood.
#
#
# c. Deep Learning -- it is a method in AI that teaches computer to process data in a way that is inspired by the human brain.
#
# e.g. -- AI model learns to ride a drone.

# %% [markdown]
# Q2- What is supervised learning ? List some examples of supervised learning.
#
# in supervised learning you use input datset and a desired output value to train the model.
#
# e.g. question and answer, image recognition

# %% [markdown]
# Q3- What is unsupervised learning ? List some examples of unsupervised learning.
#
# in unsupervised learning only unlabeled data is used to train a model
#
# e.g. -- image generation, video generation, chatting

# %% [markdown]
# Q4- What is the difference between AI, ML, DL, and DS?
#
# Artificial Intelligence is a branch of computer science. It involves building smart machines capable of performing tasks that need human intelligence.
#
# Machine Learning is the subsection of artificial intelligence based on algorithms and data usage.
#
# Deep learning is a subfield of artificial intelligence. It uses a multi-layered structure of algorithms called a neural network.
#
# Data science is a discipline that uses various technologies and methods to analyze data. It combines computational science, statistics, mathematics, and company or business knowledge.
#
# ![Data-Science-1-2.png.webp](data:image/webp;base64,...)

# %% [markdown]
# Q5- What are the main differences between supervised, unsupervised, and semi-supervised learning ?
#
# in supervised learning you use input datset and a desired output value to train the model.
#
# in unsupervised learning only unlabeled data is used to train a model
#
# semi-supervised learning offers a combination of supervised and usupervised learnig

# %% [markdown]
# Q6- What is train, test and validation split? Explain the importance of each term.
#
# train data -- this is used to train the model only.
#
# validation datset -- this is used to hyper tune the parameters
#
# test data -- this is used to test the model. it is kpt isolated from ttain and validate dataset.

# %% [markdown]
# Q7- How can unsupervised learning be used in anomaly detection?
#
# Unsupervised anomaly detection involves an unlabeled dataset. It assumes that the majority data points in the unlabeled dataset are “normal” and it looks for data points that differs from the “normal” data points.

# %% [markdown]
# Q8- List down some commonly used supervised learning algorithms and unsupervised learning algorithms.
#
# supervised learning -- linear classifiers, support vector machines (SVM), decision trees, k-nearest neighbor, and random forest
#
# unsupervised learning -- K-means clustering, KNN (k-nearest neighbors), Hierarchal clustering, Anomaly detection, Neural Networks.
