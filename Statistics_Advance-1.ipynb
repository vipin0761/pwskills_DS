# %% [markdown]
# <a href="https://colab.research.google.com/github/vipin0761/pwskills_DS/blob/main/Statistics_Advance-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1. What is the Probability density function?
#
# The probability density function (PDF) is a statistical expression that defines the probability that some outcome will occur.

# %% [markdown]
# Q2. What are the types of Probability distribution?
#
# 1. probability density function
# 2. probability mass function
# 3. cumulative distribution function

# %% [markdown]
# Q3. Write a Python function to calculate the probability density function of a normal distribution with
# given mean and standard deviation at a given point.

# %%
import scipy.stats as stats
import seaborn as sns

data =stats.norm(scale=1, loc=0).rvs(1000)

ax = sns.histplot(data)
ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'Normal Distribution'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# Q4. What are the properties of Binomial distribution? Give two examples of events where binomial
# distribution can be applied.
#
# this is a distribution which is used for a series of events where there are 2 outcomes of each event and each event is independent of other event
#
# 1. n coin flips
# 2. n matches

# %% [markdown]
# Q5. Generate a random sample of size 1000 from a binomial distribution with probability of success 0.4
# and plot a histogram of the results using matplotlib.

# %%
import seaborn as sns
import numpy as np

n, p = 1000, .4
data = np.random.binomial(n, p, 10000)

ax = sns.histplot(data)
ax.set(xlabel='Binomial Distribution', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'Binomial Distribution'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# Q6. Write a Python function to calculate the cumulative distribution function of a Poisson distribution
# with given mean at a given point.

# %%
from scipy.stats import poisson

print(poisson.cdf(k=20, mu=15))
# Out:
# 0.9170290899685397

# %% [markdown]
# Q7. How Binomial distribution different from Poisson distribution?
#
# Binomial distribution describes the distribution of binary data from a finite sample. Thus it gives the probability of getting r events out of n trials. Poisson distribution describes the distribution of binary data from an infinite sample. Thus it gives the probability of getting r events in a population.

# %% [markdown]
# Q8. Generate a random sample of size 1000 from a Poisson distribution with mean 5 and calculate the
# sample mean and variance.

# %%
from scipy.stats import poisson

ps = poisson.rvs(mu=5, size=1000)
print(ps.mean())
print(ps.std())
# Out:
# 4.976
# 2.2202306186520353

# %% [markdown]
# Q9. How mean and variance are related in Binomial distribution and Poisson distribution?
#
# In binomial distribution Mean > Variance while in poisson distribution mean = variance.

# %% [markdown]
# Q10. In normal distribution with respect to mean position, where does the least frequent data appear?
#
# on the right and left ends of the spectrum at least 3 standard deviations away from the mean
