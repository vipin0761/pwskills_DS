# %% [markdown]
# <a href="https://colab.research.google.com/github/vipin0761/pwskills_DS/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.
#
#
# matplotlib is a visualization library used to visualize data in the form of graphs to get a better understanding of the underlying trend within the data.
# 1. line
# 2. bar
# 3. pie
# 4. scatter
# 5. Histogram

# %%
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# scatter plot represents the data points as single piints along a x-y axis stystem

import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

import matplotlib.pyplot as plt

# %%
plt.xlabel('xlabel')
plt.ylabel('Ylabel')
plt.title('Scatter Plot')
plt.scatter(x,y)

# %%
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:


import numpy as np

chart = plt.plot()
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(2,2,1)
plt.plot(x1,y1)
plt.subplot(2,2,2)
plt.plot(x2,y2)
plt.subplot(2,2,3)
plt.plot(x3,y3)
plt.subplot(2,2,4)
plt.plot(x4,y4)
# Out:
# <ipython-input-9-313560ae8f38>:16: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2,2,1)

# %%
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# bar plot is a graphical representation of data in numerical and textual field respectively


import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# it shows summary of the set of data values having properties like minimum, first quartile, median, third quartile
# and maximum. In the box plot, a box is created from the first quartile to the third quartile, a vertical line
# is also there which goes through the box at the median. Here x-axis denotes the data to be plotted while the y-axis shows the frequency distribution
box1 = np.random.normal(100, 10, 200)

plt.boxplot(box1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e909dce1240>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e909dce1630>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e909dce0a30>],
#  'medians': [<matplotlib.lines.Line2D at 0x7e909dce24d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7e909dce16f0>],
#  'means': []}

# %%
box2 = np.random.normal(90, 20, 200)
plt.boxplot(box2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e909dd88130>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e909dd88670>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e909dd73e50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7e909dd88bb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7e909dd88e50>],
#  'means': []}
